# %% [markdown]
# <a href="https://colab.research.google.com/github/nkumari8-star/-AI-Nidhi-5825/blob/main/Hangman_prolog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def hangman():
    words = ["python", "computer", "science", "program", "hangman", "student"]
    word = random.choice(words)
    guessed_letters = []
    wrong_guesses = 0
    max_wrong = 6

    print("🎮 Welcome to Hangman Game!")

    while wrong_guesses < max_wrong:
        display_word = ""
        for letter in word:
            if letter in guessed_letters:
                display_word += letter + " "
            else:
                display_word += "_ "

        print("\nWord:", display_word)
        print("Guessed letters:", guessed_letters)
        print("Wrong guesses left:", max_wrong - wrong_guesses)

        if "_" not in display_word:
            print("\n🎉 Congratulations! You guessed the word:", word)
            return

        guess = input("Enter a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("❌ Please enter only one alphabet.")
            continue

        if guess in guessed_letters:
            print("⚠ You already guessed that letter.")
            continue

        guessed_letters.append(guess)

        if guess not in word:
            wrong_guesses += 1
            print("❌ Wrong guess!")

    print("\n💀 Game Over! The word was:", word)


# Run the game
hangman()
# Out:
# 🎮 Welcome to Hangman Game!
#
# Word: _ _ _ _ _ _ _
# Guessed letters: []
# Wrong guesses left: 6
# Enter a letter: p
#
# Word: p _ _ _ _ _ _
# Guessed letters: ['p']
# Wrong guesses left: 6
# Enter a letter: o
#
# Word: p _ o _ _ _ _
# Guessed letters: ['p', 'o']
# Wrong guesses left: 6
# Enter a letter: r
#
# Word: p r o _ r _ _
# Guessed letters: ['p', 'o', 'r']
# Wrong guesses left: 6
# Enter a letter: s
# ❌ Wrong guess!
#
# Word: p r o _ r _ _
# Guessed letters: ['p', 'o', 'r', 's']
# Wrong guesses left: 5
# Enter a letter: e
# ❌ Wrong guess!
#
# Word: p r o _ r _ _
# Guessed letters: ['p', 'o', 'r', 's', 'e']
# Wrong guesses left: 4
# Enter a letter: s
# ⚠ You already guessed that letter.
#
# Word: p r o _ r _ _
# Guessed letters: ['p', 'o', 'r', 's', 'e']
# Wrong guesses left: 4
# Enter a letter: a
#
# Word: p r o _ r a _
# Guessed letters: ['p', 'o', 'r', 's', 'e', 'a']
# Wrong guesses left: 4
# Enter a letter: c
# ❌ Wrong guess!
#
# Word: p r o _ r a _
# ...
